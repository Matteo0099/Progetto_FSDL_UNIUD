# %%
# %%html
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:20px;}
# p{font-size:20px!important;} .jp-RenderedHTMLCommon p, ul li {font-size:17px!important}
# .reveal h2{padding-top:1em!important;}
# h3{font-weight:400!important;font-size:21px!important}
# </style>
#
# <h1>Parco auto circolante in Italia per classe euro</h1>
#
# <h3>La mia ricerca si è concentrata nell'analizzare dati per comprendere la situazione attuale italiana riguardante
# l'inquinamento atmosferico, e prevedere le eventuali scelte future che riguarderanno le norme anti-inquinamento.</h3>
# Out:
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:20px;}
# p{font-size:20px!important;} .jp-RenderedHTMLCommon p, ul li {font-size:17px!important}
# .reveal h2{padding-top:1em!important;}
# h3{font-weight:400!important;font-size:21px!important}
# </style>
#
# <h1>Parco auto circolante in Italia per classe euro</h1>
#
# <h3>La mia ricerca si è concentrata nell'analizzare dati per comprendere la situazione attuale italiana riguardante
# l'inquinamento atmosferico, e prevedere le eventuali scelte future che riguarderanno le norme anti-inquinamento.</h3>

# %%
# %%html
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:25px!important;font-weight:600} .ital{font-style:italic;font-size:19px;}
# p,ul>*{font-size:18px!important;}
# .reveal h2{padding-top:1em!important;}
# </style>
#
# <h2>Le domande principali che mi sono posto:</h2>
# <ul>
#     <li>Che impatto hanno i veicoli sull'ambiente?</li>
#     <li>C'è un agente chimico più inquinante di altri?</li>
#     <li>C'è davvero così tanta differenza tra le classi euro dei veicoli?</li>
#     <li>All'aumentare dei veicoli, essendo più ecologici, aumentano anche i valori inquinanti?</li>
# </ul>
#
# <p class="ital">...altri concetti teorici nella prossima slide...</p>
# Out:
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:25px!important;font-weight:600} .ital{font-style:italic;font-size:19px;}
# p,ul>*{font-size:18px!important;}
# .reveal h2{padding-top:1em!important;}
# </style>
#
# <h2>Le domande principali che mi sono posto:</h2>
# <ul>
#     <li>Che impatto hanno i veicoli sull'ambiente?</li>
#     <li>C'è un agente chimico più inquinante di altri?</li>
#     <li>C'è davvero così tanta differenza tra le classi euro dei veicoli?</li>
#     <li>All'aumentare dei veicoli, essendo più ecologici, aumentano anche i valori inquinanti?</li>
# </ul>
#
# <p class="ital">...altri concetti teorici nella prossima slide...</p>

# %%
# %%html
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# p{font-size:19px!important;}
# .link{color: blue; text-decoration:none;} .link:hover{text-decoration:underline;} .fn{font-size:14px;}
# .table{text-align:center;} span.desc{font-size:18px!important;font-weight:400!important}
# </style>
#
# <h1>Concetti da sapere per capire le classi euro dei veicoli</h1>
# <span class='desc'>Le varie classi euro sono state introdotte in anni differenti, a seconda della legge in vigore negli anni passati</span>
# <span class='desc'>Questa è la lista completa della suddivisione delle classi euro a seconda dell' anno di introduzione:</span>
# <br>
# <ul>
#     <li>Euro 1: 1992</li>
#     <li>Euro 2: 1995</li>
#     <li>Euro 3: 1999</li>
#     <li>Euro 4: 2005</li>
#     <li>Euro 5: 2008</li>
#     <li>Euro 6: 2014</li>
# </ul>
# <p class="fn">fonte: <a class="link" href="https://it.wikipedia.org/wiki/Standard_europei_sulle_emissioni_inquinanti" target="_blank">wikipedia</a></p>
# Out:
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# p{font-size:19px!important;}
# .link{color: blue; text-decoration:none;} .link:hover{text-decoration:underline;} .fn{font-size:14px;}
# .table{text-align:center;} span.desc{font-size:18px!important;font-weight:400!important}
# </style>
#
# <h1>Concetti da sapere per capire le classi euro dei veicoli</h1>
# <span class='desc'>Le varie classi euro sono state introdotte in anni differenti, a seconda della legge in vigore negli anni passati</span>
# <span class='desc'>Questa è la lista completa della suddivisione delle classi euro a seconda dell' anno di introduzione:</span>
# <br>
# <ul>
#     <li>Euro 1: 1992</li>
#     <li>Euro 2: 1995</li>
#     <li>Euro 3: 1999</li>
#     <li>Euro 4: 2005</li>
#     <li>Euro 5: 2008</li>
#     <li>Euro 6: 2014</li>
# </ul>
# ...

# %%
# %%html
# <style>
# .title{font-size:17px!important;font-weight:700;} p,ul,h2,h3,h4{font-size:15px;font-weight:400;margin:0.4rem 0!important} .ital{font-style:italic;font-size:15px!important;}
# .link{color: blue; text-decoration:none;} .link:hover{text-decoration:underline;} .fn{font-size:14px!important;}
# .reveal table th, .reveal table td{text-align:center!important;font-size:13px!important;margin:0!important}
# .jp-RenderedHTMLCommon p, .jp-RenderedHTMLCommon ul>* {font-size: 18px !important;}
# .jp-RenderedHTMLCommon p, .pers,jp-RenderedHTMLCommon ul li{padding-lef:.75em!important; margin:0.2rem 0!important;font-size:16px!important;}
# span{margin-left:0!important;padding-left:0!important;font-size:17px!important} p{font-size:14px!important;}
# </style>
#
# <h2>Quantità in grammi / km concessi per classe euro e distinzione tra diesel e benzina:</h2>
# <ul class='pers' style='font-size:17px!important'>
#      <li>↑ = Tendenza all'<strong>aumento</strong> dell'ozono</li>
#     <li>↓ = Tendenza alla <strong>riduzione</strong> dell'ozono</li>
#     <li>↑↑ > ↑  = Maggiore è il numero di frecce, più <strong>intenso</strong> è l'effetto</li>
#     <li> →  = <strong>Non cambia</strong> i livelli di ozono.</li>
#     <li><strong>Differenze carburanti:</strong> I veicoli a benzina hanno generalmente un impatto minore sull'O₃ rispetto ai diesel.</li>
# </ul>
# <table>
#     <tr class="header">
#         <th rowspan="2">Classe</th>
#         <th rowspan="2">Carburante</th>
#         <th rowspan="2">Data</th>
#         <th colspan="2">Emissioni dirette</th>
#         <th colspan="2">Impatto indiretto</th>
#     </tr>
#     <tr class="subheader">
#         <th>CO (g/km)</th>
#         <th>NOx (g/km)</th>
#         <th>Formazione O₃</th>
#         <th>Stima CO₂</th>
#     </tr>
#     <!-- Diesel Rows -->
#     <tr class="diesel">
#         <td>Euro 1</td><td>Diesel</td><td>Giugno 1992</td><td>2.72</td><td>–</td><td>↑↑↑</td><td>>200 g/km</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 1</td><td>Benzina</td><td>Giugno 1992</td><td>2.72</td><td>–</td><td>↑↑</td><td>~180 g/km</td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 2</td><td>Diesel</td><td>Gennaio 1996</td><td>1.0</td><td>–</td><td>↑↑</td><td>~190 g/km</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 2</td><td>Benzina</td><td>Gennaio 1996</td><td>2.2</td><td>–</td><td>↑</td><td>~170 g/km</td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 3</td><td>Diesel</td><td>Gennaio 2000</td><td>0.66</td><td>0.500</td><td>→</td><td>~180 g/km</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 3</td><td>Benzina</td><td>Gennaio 2000</td><td>2.3</td><td>0.150</td><td>↓</td><td>~160 g/km</td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 4</td><td>Diesel</td><td>Gennaio 2005</td><td>0.50</td><td>0.250</td><td>↓↓</td><td>~170 g/km</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 4</td><td>Benzina</td><td>Gennaio 2005</td><td>1.0</td><td>0.080</td><td>↓↓</td><td>~150 g/km</td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 5a</td><td>Diesel</td><td>Sett. 2009</td><td>0.50</td><td>0.180</td><td>↓↓↓</td><td>~160 g/km</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 5a</td><td>Benzina</td><td>Sett. 2009</td><td>1.0</td><td>0.060</td><td>↓</td><td>~140 g/km</td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 6b</td><td>Diesel</td><td>Sett. 2014</td><td>0.50</td><td>0.080</td><td>↓↓↓</td><td>~150 g/km</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 6b</td><td>Benzina</td><td>Sett. 2014</td><td>1.0</td><td>0.060</td><td>↓</td><td>~130 g/km</td>
#     </tr>
# </table>
# Out:
# <style>
# .title{font-size:17px!important;font-weight:700;} p,ul,h2,h3,h4{font-size:15px;font-weight:400;margin:0.4rem 0!important} .ital{font-style:italic;font-size:15px!important;}
# .link{color: blue; text-decoration:none;} .link:hover{text-decoration:underline;} .fn{font-size:14px!important;}
# .reveal table th, .reveal table td{text-align:center!important;font-size:13px!important;margin:0!important}
# .jp-RenderedHTMLCommon p, .jp-RenderedHTMLCommon ul>* {font-size: 18px !important;}
# .jp-RenderedHTMLCommon p, .pers,jp-RenderedHTMLCommon ul li{padding-lef:.75em!important; margin:0.2rem 0!important;font-size:16px!important;}
# span{margin-left:0!important;padding-left:0!important;font-size:17px!important} p{font-size:14px!important;}
# </style>
#
# <h2>Quantità in grammi / km concessi per classe euro e distinzione tra diesel e benzina:</h2>
# <ul class='pers' style='font-size:17px!important'>
#      <li>↑ = Tendenza all'<strong>aumento</strong> dell'ozono</li>
# ...

# %%
# %%html
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:15px;}
#  ul li {padding-lef:.65em!important; font-size:14px!important;} h3{font-size:24px!important;font-weight:400!important} h4{font-size:16px!important;font-weight:400!important}
# .link{color: blue; text-decoration:none;} .link:hover{text-decoration:underline;} .fn{font-size:14px;}
# table td, table th{text-align:center!important;font-size:15px!important} ul li.pad{padding-top:7px!important}
# </style>
#
# <h4><strong>PM</strong>: abbreviazione di Particulate Matter, ovvero materiale particolato sospeso nell'aria</h4>
# <h4>Cosa si intende per <strong>PM 10</strong> E <strong>PM 2.5</strong>?</h4>
# <ul>
#     <li><strong>PM10</strong>: particelle con diametro ≤ 10 micrometri</li>
#     <li>Pericolosità PM10: le particelle possono penetrare nel tratto respiratorio superiore(naso,gola)</li>
#     <li class="pad"><strong>PM2.5</strong>: particelle con diametro ≤ 2.5 micrometri</li>
#     <li>Pericolosità PM2.5: più fini e pericolose, raggiungono i polmoni profondi e il sangue</li>
# </ul>
#
# <table>
#     <tr class="header">
#         <th rowspan="2">Classe</th>
#         <th rowspan="2">Carburante</th>
#         <th colspan="2">Particolato</th>
#         <th rowspan="2">Note</th>
#     </tr>
#     <tr class="subheader">
#         <th>PM 10 (g/km)</th>
#         <th>PM 2.5 (g/km)</th>
#     </tr>
#     <!-- Diesel Rows -->
#     <tr class="diesel">
#         <td>Euro 1</td><td>Diesel</td><td>0.14</td><td>~0.12</td><td>Nessun filtro</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 1</td><td>Benzina</td><td>–</td><td>–</td><td></td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 2</td><td>Diesel</td><td>0.08</td><td>~0.07</td><td></td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 2</td><td>Benzina</td><td>–</td><td>–</td><td></td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 3</td><td>Diesel</td><td>0.05</td><td>~0.04</td><td></td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 3</td><td>Benzina</td><td>–</td><td>–</td><td></td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 4</td><td>Diesel</td><td>0.025</td><td>~0.020</td><td></td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 4</td><td>Benzina</td><td>–</td><td>–</td><td></td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 5a</td><td>Diesel</td><td>0.005</td><td>~0.004</td><td>DPF obbligatori</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 5a</td><td>Benzina</td><td>0.005</td><td>~0.004</td><td>Limitazione GDI</td>
#     </tr>
#     <tr class="diesel">
#         <td>Euro 6b</td><td>Diesel</td><td>0.0045</td><td>~0.0036</td><td>Nanoparticelle monitorate</td>
#     </tr>
#     <tr class="benzina">
#         <td>Euro 6b</td><td>Benzina</td><td>0.0045</td><td>~0.0036</td><td></td>
#     </tr>
# </table>
# Out:
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:15px;}
#  ul li {padding-lef:.65em!important; font-size:14px!important;} h3{font-size:24px!important;font-weight:400!important} h4{font-size:16px!important;font-weight:400!important}
# .link{color: blue; text-decoration:none;} .link:hover{text-decoration:underline;} .fn{font-size:14px;}
# table td, table th{text-align:center!important;font-size:15px!important} ul li.pad{padding-top:7px!important}
# </style>
#
# <h4><strong>PM</strong>: abbreviazione di Particulate Matter, ovvero materiale particolato sospeso nell'aria</h4>
# <h4>Cosa si intende per <strong>PM 10</strong> E <strong>PM 2.5</strong>?</h4>
# <ul>
#     <li><strong>PM10</strong>: particelle con diametro ≤ 10 micrometri</li>
#     <li>Pericolosità PM10: le particelle possono penetrare nel tratto respiratorio superiore(naso,gola)</li>
# ...

# %%
# %%html
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:20px!important;}
# p,ul>*{font-size:18px!important;}
# </style>
#
# <h1>Classificazione veicoli in base alla classe EURO</h1>
# <p>In questo grafico si mostra il numero di veicoli circolanti nel parco auto italiano per suddivisione in base alla classe euro.</p>
# <p><strong>Valori euro più alti</strong> corrispondono a una maggiore efficienza ed a un <strong>minor inquinamento</strong> atmosferico</p>
# Out:
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:20px!important;}
# p,ul>*{font-size:18px!important;}
# </style>
#
# <h1>Classificazione veicoli in base alla classe EURO</h1>
# <p>In questo grafico si mostra il numero di veicoli circolanti nel parco auto italiano per suddivisione in base alla classe euro.</p>
# <p><strong>Valori euro più alti</strong> corrispondono a una maggiore efficienza ed a un <strong>minor inquinamento</strong> atmosferico</p>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_raw = pd.read_csv("dataset/parco_veicoli2.csv", encoding='utf8', header=None)
df = df_raw.iloc[1:9].copy()
df.columns = ['Alimentazione', 'EURO 0', 'EURO 1', 'EURO 2', 'EURO 3', 'EURO 4', 'EURO 5', 'EURO 6']

def formatta(x):
    if isinstance(x, str):
        x = x.replace(' ', '')
        x = x.replace(' ', '')
        x = x.replace('.', '')
        x = x.replace(',', '')
        x = x.replace('-', '')
    return pd.to_numeric(x)

for col in df.columns[1:]:
    df[col] = df[col].apply(formatta)

df.head()
df_long = df.melt(id_vars="Alimentazione", 
                  var_name="Classe Euro", 
                  value_name="Numero Veicoli")

plt.figure(figsize=(14, 6))
sns.barplot(data=df_long, x="Classe Euro", y="Numero Veicoli", hue="Alimentazione")
plt.yscale('log')
plt.ylim(1e2, 10e7) #max 8 mln
plt.grid("true")

plt.xlabel("Classe Euro", fontsize=14)
plt.ylabel("Numero Veicoli", fontsize=14)


plt.title("Distribuzione veicoli per Classe Euro (scala logaritmica)")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper left', prop={'size': 9})
plt.tight_layout()
plt.savefig('heatmap_veicoli_euro.png')
plt.savefig('classi_euro_circolanti.png', dpi=300)
plt.show()

# %%
# %%html
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# </style>
#
# <h1>Concentrazione di veicoli circolanti per classe euro</h1>
# Out:
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# </style>
#
# <h1>Concentrazione di veicoli circolanti per classe euro</h1>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_raw = pd.read_csv("dataset/parco_veicoli2.csv", encoding='utf8', header=None)
df = df_raw.iloc[1:9].copy()
df.columns = ['Alimentazione', 'EURO 0', 'EURO 1', 'EURO 2', 'EURO 3', 'EURO 4', 'EURO 5', 'EURO 6']

def formatta(x):
    if isinstance(x, str):
        x = x.replace(' ', '').replace(' ', '').replace('.', '').replace(',', '').replace('-', '')
    return pd.to_numeric(x, errors='coerce')

for col in df.columns[1:]:
    df[col] = df[col].apply(formatta)

plt.figure(figsize=(12, 6))  #pollici(1=2,54cm)
heatmap_data = df.set_index('Alimentazione')
cmap = sns.color_palette(["#fffded", "#fff8ba", "#ffd700", "#ffa500", "#ff0000"], as_cmap=True)
sns.heatmap(
    heatmap_data, 
    annot=True, 
    fmt=".0f", 
    cmap=cmap,
    linewidths=0.5,
    linecolor="gray",
    cbar_kws={'label': 'Numero veicoli (mln)'}
)
plt.grid(False)
plt.title("Concentrazione veicoli per Classe Euro e Alimentazione", pad=15)
#plt.xlabel("Classe Euro")
plt.ylabel("Tipo di Alimentazione")
plt.xticks(fontsize=10)
plt.tight_layout()
plt.savefig('heatmap_veicoli_euro.png', dpi=300)
plt.show()

# %%
# %%html
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:20px;}
# img{margin:0!important}
# </style>
#
# <h1>Inquinamento e classi ambientali più stringenti</h1>
# <p>Correlazione tra classi di inquinamento dei veicoli circolanti e co2 emessa.</p>
# Out:
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:20px;}
# img{margin:0!important}
# </style>
#
# <h1>Inquinamento e classi ambientali più stringenti</h1>
# <p>Correlazione tra classi di inquinamento dei veicoli circolanti e co2 emessa.</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

euro_intro = {
    'EURO 1': 1992,
    'EURO 2': 1995,
    'EURO 3': 1999,
    'EURO 4': 2005,
    'EURO 5': 2008,
    'EURO 6': 2014
}

co2 = pd.read_csv("dataset/storico_co2_italia.csv", encoding='utf8', header=None)
co2_trasporti = co2[co2[0].str.contains("1.A.3.  Transport", na=False)].iloc[0, 1:35]

def clean_num(x):
    if isinstance(x, str):
        x = x.replace(' ','').replace(' ','').replace('.','').replace(',','').replace('-','0')
    return pd.to_numeric(x, errors='coerce')

co2_values = [clean_num(x) for x in co2_trasporti]
years = list(range(1990, 2024))

plt.figure(figsize=(14, 8), dpi=100)
plt.plot(years, co2_values, 'r-', linewidth=2.5, marker='o', markersize=5, label='Emissioni CO2 trasporti')
colors = ['green', 'blue', 'purple', 'orange', 'brown', 'gray']

for i, (euro, year) in enumerate(euro_intro.items()):
    plt.axvline(x=year, color=colors[i], linestyle='--', linewidth=1.5, alpha=0.7)
    plt.text(year, plt.ylim()[1]*0.9, euro, rotation=90, va='top', ha='right', 
             color=colors[i], fontweight='bold', backgroundcolor='white', fontsize=12)

plt.fill_between(years, co2_values, alpha=0.1, color='gray')
plt.title('Impatto delle Classi Euro sulle Emissioni di CO2 (1990-2023)', pad=20, fontsize=18)
plt.xlabel('Anno', fontsize=14)
plt.ylabel('Emissioni CO2 (kt)', fontsize=14)
plt.grid(True, linestyle='-', alpha=.4)
plt.legend(loc='upper left', fontsize=12)
plt.ylim(7e6, 14e6)
plt.ylabel('Emissioni CO2 (×10⁶ tonnellate)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.savefig('classi_euro_emiss.png', dpi=300)
plt.show()

# %%
# %%html
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# </style>
#
# <h1>Dati riguardanti il PM 2.5</h1>
# Out:
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# </style>
#
# <h1>Dati riguardanti il PM 2.5</h1>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pm25_file = 'dataset/altrids/pm25.csv'
df_pm25 = pd.read_csv(pm25_file, sep=';', decimal=',')
df_pm25 = df_pm25.melt(id_vars='Category', var_name='Source', value_name='PM2.5')
df_pm25['PM2.5'] = df_pm25['PM2.5'].astype(float)
df_pm25['Category'] = df_pm25['Category'].astype(int)

sorgenti = ['Trasporti Stradali', 'Altre Sorgenti Mobili']
df_filtrato = df_pm25[df_pm25['Source'].isin(sorgenti)]

g = sns.FacetGrid(df_filtrato, col="Source", height=4)
g.map(sns.scatterplot, "Category", "PM2.5", alpha=0.7)
g.set_axis_labels("Anno", "PM2.5 (kt)")
for ax in g.axes.flat:
    ax.grid(True, linestyle='-', alpha=0.3)

g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("PM2.5", fontsize=16)
plt.savefig("facetgrid_pm25.png", dpi=350)
plt.show()

# %%
# %%html
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# p,ul>*{font-size:20px!important;}
# </style>
#
# <h1>Dati riguardanti il PM 10</h1>
# Out:
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# p,ul>*{font-size:20px!important;}
# </style>
#
# <h1>Dati riguardanti il PM 10</h1>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pm10_file = 'dataset/altrids/pm10.csv'
df_pm10 = pd.read_csv(pm10_file, sep=';', decimal=',')

df_pm10 = df_pm10.melt(id_vars='Category', var_name='Source', value_name='PM10')
df_pm10['PM10'] = df_pm10['PM10'].astype(float)
df_pm10['Category'] = df_pm10['Category'].astype(int)
sorgenti = ['Trasporti Stradali', 'Altre Sorgenti Mobili']
df_filtrato = df_pm10[df_pm10['Source'].isin(sorgenti)]

g = sns.FacetGrid(df_filtrato, col="Source", height=4)
g.map(sns.scatterplot, "Category", "PM10", alpha=0.7)
g.set_axis_labels("Anno", "PM10 (kt)")
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("PM10", fontsize=15)
plt.savefig("facetgrid_pm10.png", dpi=350)
plt.show()

# %%
# %%html
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# p,ul>*{font-size:17px!important;}  span.def{font-size:19px!important;font-weight:700!important}
# </style>
#
# <h1>Dati riguardanti il NOx / COVNM</h1>
# <span class='def'>Definizioni:</span>
# <ul>
#     <li><strong>NOx</strong>: Ossidi di azoto (NO+NO₂), inquinanti da combustione che causano smog e irritazioni respiratorie.</li>
#     <li><strong>COVNM</strong>: Composti Organici Volatili <u>Non Metanici</u> (es. benzene, toluene), precursori dell'ozono e cancerogeni.</li>
# </ul>
# <p>Gli ossidi di azoto (NO+NO₂) sono gli agenti più inquinanti.</p>
# Out:
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# p,ul>*{font-size:17px!important;}  span.def{font-size:19px!important;font-weight:700!important}
# </style>
#
# <h1>Dati riguardanti il NOx / COVNM</h1>
# <span class='def'>Definizioni:</span>
# <ul>
#     <li><strong>NOx</strong>: Ossidi di azoto (NO+NO₂), inquinanti da combustione che causano smog e irritazioni respiratorie.</li>
#     <li><strong>COVNM</strong>: Composti Organici Volatili <u>Non Metanici</u> (es. benzene, toluene), precursori dell'ozono e cancerogeni.</li>
# </ul>
# <p>Gli ossidi di azoto (NO+NO₂) sono gli agenti più inquinanti.</p>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

nox_file = 'dataset/altrids/nox.csv'

df_nox = pd.read_csv(nox_file, sep=';', decimal=',')
df_nox = df_nox.rename(columns={"Category": "Anno"})
df_nox['Anno'] = df_nox['Anno'].astype(int)

plt.figure(figsize=(10, 5))
sns.lineplot(data=df_nox, x='Anno', y='NOx', label='NOx')
sns.lineplot(data=df_nox, x='Anno', y='COVNM', label='COVNM')
plt.title('Emissioni di NOx e COVNM nel Tempo')
plt.xlabel('Anni', fontsize=12)
plt.ylabel('kt (kiloton)', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('dati_NOx_COVNM.png', dpi=300)
plt.show()

# %%
# %%html
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:17px;}
# </style>
#
# <h1>All'aumentare dei veicoli, aumentano anche i valori inquinanti?🤔</h1>
# Out:
# <style>
# .reveal h1{font-size:36px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:17px;}
# </style>
#
# <h1>All'aumentare dei veicoli, aumentano anche i valori inquinanti?🤔</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

euro_intro = {
    'EURO 1': 1992,
    'EURO 2': 1995,
    'EURO 3': 1999,
    'EURO 4': 2005,
    'EURO 5': 2008,
    'EURO 6': 2014
}

def carica_dato(path):
    return pd.read_csv(path, sep=';', decimal=',')

pm25 = carica_dato('dataset/altrids/pm25.csv')
pm10 = carica_dato('dataset/altrids/pm10.csv')
nox  = carica_dato('dataset/altrids/nox.csv')

df = pd.DataFrame({
    'Anno': pm25['Category'].astype(int),
    'PM2.5': pm25['Trasporti Stradali'],
    'PM10': pm10['Trasporti Stradali'],
    'NOx': nox['NOx']
})
df_melted = df.melt(id_vars='Anno', var_name='Inquinante', value_name='Valore')

sns.set(style="whitegrid")
plt.figure(figsize=(16, 6))
sns.barplot(data=df_melted, x='Anno', y='Valore', hue='Inquinante')
anni = df['Anno'].tolist()
for label, year in euro_intro.items():
    if year in anni:
        idx = anni.index(year)
        plt.axvline(x=idx-0.94, color='gray', linestyle='--', alpha=0.8)
        plt.text(idx, plt.ylim()[1]*0.97, label, color='gray', va='top', ha='center', fontsize=15)
        
#plt.title("PM2.5, PM10, NOx e Classi Euro")
plt.xlabel("Anni", fontsize=14)
plt.ylabel("Emissioni kt/a", fontsize=14)
plt.legend(title='Inquinante')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax = plt.gca()
ax.set_xticks(ax.get_xticks()[::2])
plt.tight_layout()
plt.savefig('emissioni_veicoli_euro.png', dpi=350)
plt.show()

# %%
# %%html
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:20px!important;}h4{font-size:28px!important;font-weight:600!important;padding-top:1em!important}
# </style>
#
# <h1>Conclusioni della ricerca</h1>
# <p>L'analisi ha confermato non solo la consistenza e coerenza dei dati, ma anche la pertinenza e perfetta corrispondenza dei valori con le normative europee sulle classi Euro e gli agenti inquinanti, rispettando i limiti e seguendo la coerenza generale.</p>
# <h4>Osservazione: </h4>
# <p>Come si è potuto evincere dai vari grafici, la classe "euro" delle decine di milioni di veicoli circolanti in Italia ha aiutato per diminuire le emissioni, diminuendo drasticamente i valori della CO2, NO2, O3 e pm2.5 con pm10.</p>
# <p>I risultati dimostrano come i benefici delle politiche di riduzione delle emissioni richiedano spesso periodi di tempo prolungati per manifestarsi in modo significativo, a causa dei complessi meccanismi di risposta del sistema atmosferico e della Terra.</p>
# Out:
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:20px!important;}h4{font-size:28px!important;font-weight:600!important;padding-top:1em!important}
# </style>
#
# <h1>Conclusioni della ricerca</h1>
# <p>L'analisi ha confermato non solo la consistenza e coerenza dei dati, ma anche la pertinenza e perfetta corrispondenza dei valori con le normative europee sulle classi Euro e gli agenti inquinanti, rispettando i limiti e seguendo la coerenza generale.</p>
# <h4>Osservazione: </h4>
# <p>Come si è potuto evincere dai vari grafici, la classe "euro" delle decine di milioni di veicoli circolanti in Italia ha aiutato per diminuire le emissioni, diminuendo drasticamente i valori della CO2, NO2, O3 e pm2.5 con pm10.</p>
# ...

# %%
# %%html
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# p,ul>*{font-size:18px!important;} a.link{color: blue!important; text-decoration:none!important;} a.link:hover{text-decoration:underline!important;} table>*{font-size:18px!important}
# </style>
#
# <h1>Fonti da cui ho preso Dataset e Informazioni:</h1>
# <ul>
#      <li><a href="https://it.wikipedia.org/wiki/Standard_europei_sulle_emissioni_inquinanti" target="_blank" class="link">Wikipedia</a></li>
#     <li><a href="https://esploradati.istat.it/databrowser/#/it/dw" target="_blank" class="link">Istat</a></li>
#     <li><a href="https://indicatoriambientali.isprambiente.it/it/temi/174" target="_blank" class="link">ISPRA ambiente</a></li>
#     <li><a href="https://www.anfia.it/it/attivita/studi-e-statistiche/automobile-in-cifre/statistiche-italia/parco-circolante/autoveicoli-motor-vehicles" target="_blank" class="link">ANFIA</a></li>
# </ul>
#
# <h2>Autori del dataset ed anno di pubblicazione:</h2>
# <table border="1">
#   <thead>
#     <tr>
#       <th>Autore</th>
#       <th>Anno</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ISTAT</td>
#       <td>2025</td>
#     </tr>
#     <tr>
#       <td>ISPRA</td>
#       <td>2024</td>
#     </tr>
#     <tr>
#       <td>ANFIA</td>
#       <td>2024</td>
#     </tr>
#   </tbody>
# </table>
# Out:
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:28px!important;font-weight:600} .ital{font-style:italic;font-size:18px;}
# p,ul>*{font-size:18px!important;} a.link{color: blue!important; text-decoration:none!important;} a.link:hover{text-decoration:underline!important;} table>*{font-size:18px!important}
# </style>
#
# <h1>Fonti da cui ho preso Dataset e Informazioni:</h1>
# <ul>
#      <li><a href="https://it.wikipedia.org/wiki/Standard_europei_sulle_emissioni_inquinanti" target="_blank" class="link">Wikipedia</a></li>
#     <li><a href="https://esploradati.istat.it/databrowser/#/it/dw" target="_blank" class="link">Istat</a></li>
#     <li><a href="https://indicatoriambientali.isprambiente.it/it/temi/174" target="_blank" class="link">ISPRA ambiente</a></li>
# ...

# %%
# %%html
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:32px!important;font-weight:600} .ital{font-style:italic;font-size:15px;}
# p,ul>*{font-size:18px!important;} a.link{color: blue!important; text-decoration:none!important;} a.link:hover{text-decoration:underline!important;}
# </style>
#
# <h2>...Grazie per l'attenzione!</h2>
# Out:
# <style>
# .reveal h1{font-size:32px!important;font-weight:800;} .reveal h2{font-size:32px!important;font-weight:600} .ital{font-style:italic;font-size:15px;}
# p,ul>*{font-size:18px!important;} a.link{color: blue!important; text-decoration:none!important;} a.link:hover{text-decoration:underline!important;}
# </style>
#
# <h2>...Grazie per l'attenzione!</h2>
